# %%
# clustering + topic modeling

# %%
from src.cimba.similarity import semantic_similarity


await semantic_similarity(
    "how many customers do you have",
    "what is the customer count",
)
# Out:
# Raw semantic: 0.7298015669089359
# 0.9703936916869819

# %%
from src.cimba.similarity import normalize_tokens

tokens = normalize_tokens("what is the customer count")
print(tokens)
# Out:
# ['customer', 'count']
